# %% [markdown]
# # Random Forest
# - Decision Tree는 Overfitting 가능성이 높다는 약점이 있다. Random Forest는 여러 개의 의사결정나무(Decision Tree)를 조합하여 예측을 수행하는 앙상블 모델로, 단일 트리보다 일반화 성능이 우수하다.
# - 앙상블(Ensemble)이란 강력한 하나의 모델을 사용하는 대신 보다 약한 여러개의 모델을 조합하여 예측하는 방법이다. (random forestm, xgboost 등)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import randint
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV, RandomizedSearchCV
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.metrics import classification_report
from IPython.display import Image, display

# %matplotlib inline

# %% [markdown]
# # Random Forest (Regression)
# - 목표 : 범죄율, 방 개수, 저소득층 인구 비율 등의 데이터를 기반으로 주택 가격의 중앙값(medv)를 예측하는 회귀모델을 만드는 것

# %% [markdown]
# ## 1. Data load

# %%
# read data
boston_df = pd.read_csv('../data/Boston.csv')
boston_df.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#     black  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
boston_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    int64
#  4   nox      506 non-null    float64
#  5   rm       506 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    int64
#  9   tax      506 non-null    int64
#  10  ptratio  506 non-null    float64
#  11  black    506 non-null    float64
#  12  lstat    506 non-null    float64
#  13  medv     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
display(Image(filename='../image/random_forest_regression_col_info.png', width=600))

# %%
boston_df.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio       black  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
boston_df.shape
# Out:
# (506, 14)

# %% [markdown]
# ## 2. Preprocessing

# %% [markdown]
# ### 2-1. null 제거 -> 없음

# %%
boston_df.dropna(how='any', inplace=True)
boston_df.shape
# Out:
# (506, 14)

# %% [markdown]
# - 트리계열 모델은 비선형 모델로 분포에 영향을 크게 받지 않기 때문에 log 변환 등의 값 변환이 없어도 괜찮을 수 있다?

# %%
sns.histplot(data=boston_df, x='medv', bins=10, kde=True, color='skyblue')
plt.show()

# %%
print(scipy.stats.skew(boston_df['medv'])) # 1이상이면 log 변환 고려?
# Out:
# 1.104810822864635

# %% [markdown]
# ### 2-2. X,y 분할

# %%
X = boston_df.drop('medv', axis=1)
y = boston_df['medv']
print(X.shape, y.shape)
# Out:
# (506, 13) (506,)

# %% [markdown]
# ### 2-3. train test split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=3)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (404, 13) (102, 13) (404,) (102,)

# %% [markdown]
# ## 3. Modeling

# %%
display(Image(filename='../image/random_forest_hyperparameter_info.png', width=600))

# %% [markdown]
# - 테스트

# %%
rf_reg = RandomForestRegressor(n_estimators=500,
                               max_features=8,
                               random_state=123)

rf_reg.fit(X_train, y_train)

y_pred = rf_reg.predict(X_test)

# %%
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print("Test RMSE:", round(rmse, 2))
print("Test R²:", round(r2, 4))
# Out:
# Test RMSE: 2.59
# Test R²: 0.9192

# %% [markdown]
# - 하이퍼 파라미터 default로 설정

# %%
rf_reg = RandomForestRegressor(random_state=123)

rf_reg.fit(X_train, y_train)

y_pred = rf_reg.predict(X_test)

# %%
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print("Test RMSE:", round(rmse, 2))
print("Test R²:", round(r2, 4))
# Out:
# Test RMSE: 2.7
# Test R²: 0.9121

# %%
# max_feature에 따라 모델 성능 비교
feature_size = range(3, 12)
mse_scores = []
for size in feature_size:
    # n_jobs는 병렬 작업 수를 의미, -1일 경우 모든 프로세서 사용
    rf_regr = RandomForestRegressor(n_estimators=500, 
                                    max_features=size, 
                                    random_state=123,
                                    n_jobs=-1)
    rf_regr.fit(X_train, y_train)
    y_pred = rf_regr.predict(X_test)
    mse = mean_squared_error(y_pred, y_test)
    mse_scores.append(mse)


opt_feature = mse_scores.index(min(mse_scores)) + 3
print('feature:', opt_feature, '(', round(min(mse_scores), 3), ')')
plt.plot(feature_size, mse_scores)
plt.xlabel('Feature Size')
plt.ylabel('MSE')
plt.grid(True)
plt.show()
# Out:
# feature: 6 ( 6.688 )

# %% [markdown]
# ### 3-1. 하이퍼파라미터 튜닝

# %%
param_distributions = {
    'n_estimators': randint(2, 500),
    'max_depth': randint(5, 20),
    'min_samples_split': randint(2, 10),
    'min_samples_leaf': randint(1, 5),
    'max_features': randint(1, 10)
}

model = RandomForestRegressor(random_state=42)

random_search = RandomizedSearchCV(
    estimator=model,
    param_distributions=param_distributions,
    n_iter=30,               # 30번 샘플링해서 모델 학습
    scoring='neg_mean_squared_error',
    cv=5,
    verbose=1,
    random_state=42,
    n_jobs=-1
)

random_search.fit(X_train, y_train)

best_model = random_search.best_estimator_
print("Best params:", random_search.best_params_)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# Best params: {'max_depth': 17, 'max_features': 9, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 60}

# %%
best_model = random_search.best_estimator_

# %%
y_pred = best_model.predict(X_test)

# %%
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print("Best params:", random_search.best_params_)
print("Test RMSE:", round(rmse, 2))
print("Test R²:", round(r2, 4))
# Out:
# Best params: {'max_depth': 17, 'max_features': 9, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 60}
# Test RMSE: 2.7
# Test R²: 0.9119

# %%
# 중요한 상위 10개의 Feature 확인
feature_importance = pd.DataFrame({'feature': X_train.columns, 'importance': best_model.feature_importances_})
feature_importance.sort_values(by='importance', ascending=False)[:10]
# Out:
#     feature  importance
# 12    lstat    0.454856
# 5        rm    0.295457
# 7       dis    0.064828
# 0      crim    0.047652
# 4       nox    0.043188
# 2     indus    0.026122
# 10  ptratio    0.021305
# 6       age    0.017072
# 9       tax    0.013858
# 11    black    0.011485

# %% [markdown]
# # Random Forest (Classification)
# - 목표 : 건강 정보(나이, 흉통 유형, 콜레스테롤 수치 등)를 기반으로 심장 질환 여부(AHD) 를 예측하는 분류 모델을 구축

# %% [markdown]
# ## 1. Data load

# %%
# read data
heart_df = pd.read_csv('../data/Heart.csv', index_col=0)
heart_df.head()
# Out:
#    Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  Oldpeak  \
# 1   63    1       typical     145   233    1        2    150      0      2.3
# 2   67    1  asymptomatic     160   286    0        2    108      1      1.5
# 3   67    1  asymptomatic     120   229    0        2    129      1      2.6
# 4   37    1    nonanginal     130   250    0        0    187      0      3.5
# 5   41    0    nontypical     130   204    0        2    172      0      1.4
#
#    Slope   Ca        Thal  AHD
# 1      3  0.0       fixed   No
# 2      2  3.0      normal  Yes
# 3      2  2.0  reversable  Yes
# 4      3  0.0      normal   No
# 5      1  0.0      normal   No

# %%
heart_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 303 entries, 1 to 303
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Age        303 non-null    int64
#  1   Sex        303 non-null    int64
#  2   ChestPain  303 non-null    object
#  3   RestBP     303 non-null    int64
#  4   Chol       303 non-null    int64
#  5   Fbs        303 non-null    int64
#  6   RestECG    303 non-null    int64
#  7   MaxHR      303 non-null    int64
#  8   ExAng      303 non-null    int64
#  9   Oldpeak    303 non-null    float64
#  10  Slope      303 non-null    int64
#  11  Ca         299 non-null    float64
#  12  Thal       301 non-null    object
#  13  AHD        303 non-null    object
# dtypes: float64(2), int64(9), object(3)
# memory usage: 35.5+ KB

# %%
display(Image(filename='../image/decision_tree_classification_col_info.png', width=600))

# %%
heart_df.describe()
# Out:
#               Age         Sex      RestBP        Chol         Fbs     RestECG  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.438944    0.679868  131.689769  246.693069    0.148515    0.990099
# std      9.038662    0.467299   17.599748   51.776918    0.356198    0.994971
# min     29.000000    0.000000   94.000000  126.000000    0.000000    0.000000
# 25%     48.000000    0.000000  120.000000  211.000000    0.000000    0.000000
# 50%     56.000000    1.000000  130.000000  241.000000    0.000000    1.000000
# 75%     61.000000    1.000000  140.000000  275.000000    0.000000    2.000000
# max     77.000000    1.000000  200.000000  564.000000    1.000000    2.000000
#
#             MaxHR       ExAng     Oldpeak       Slope          Ca
# count  303.000000  303.000000  303.000000  303.000000  299.000000
# mean   149.607261    0.326733    1.039604    1.600660    0.672241
# std     22.875003    0.469794    1.161075    0.616226    0.937438
# ...

# %%
heart_df.describe(include='object')
# Out:
#            ChestPain    Thal  AHD
# count            303     301  303
# unique             4       3    2
# top     asymptomatic  normal   No
# freq             144     166  164

# %%
heart_df.shape
# Out:
# (303, 14)

# %% [markdown]
# ## 2. Preprocessing

# %% [markdown]
# ### 2-1. null 제거

# %%
heart_df.dropna(how='any', inplace=True)
heart_df.shape
# Out:
# (297, 14)

# %% [markdown]
# ### 2-2. X,y 분할

# %%
X = heart_df.drop('AHD', axis=1)
y = heart_df['AHD']

# %% [markdown]
# ### 2-3. Onehot Encoding 및 y 값 변환

# %%
# encoding할 피쳐 저장
encoding_features = list(X.select_dtypes(include='object').columns)

# %%
# 특성마다 전처리 방법 다를 때 사용
preprocessor = ColumnTransformer(
    transformers = [('encoding', OneHotEncoder(sparse_output=False), encoding_features)],
    remainder='passthrough'
)

# %%
X_e = pd.DataFrame(preprocessor.fit_transform(X), columns=preprocessor.get_feature_names_out())

# %%
# y값 변환
y = y.apply(lambda x: 1 if x == 'Yes' else 0)

# %% [markdown]
# ### 2-4. train test split

# %%
X_train, X_test, y_train, y_test = train_test_split(X_e, y, test_size=0.2, random_state=3)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (237, 18) (60, 18) (237,) (60,)

# %% [markdown]
# ### 3. Modeling

# %% [markdown]
# - Decision Tree와 Random Forest의 차이를 비교해보자

# %%
# Decision Tree Cross Validation 평가
tree_clf = DecisionTreeClassifier(random_state=123)
acc_score_t = cross_val_score(tree_clf, X_e, y, cv=7, scoring='accuracy')

# Random Forest Cross Validation 평가
rf_clf = RandomForestClassifier(random_state=123)
acc_score_r = cross_val_score(rf_clf, X_e, y, cv=7, scoring='accuracy')

# %%
print('Decision Tree: ', round(np.mean(acc_score_t), 3))
print('Random Forest: ', round(np.mean(acc_score_r), 3))
# Out:
# Decision Tree:  0.72
# Random Forest:  0.824

# %% [markdown]
# - 기본 모델로 cross_val_score로 교차검증 통해 모델 성능 평균적으로 확인해봤을 때 Random Forest가 더 높음
